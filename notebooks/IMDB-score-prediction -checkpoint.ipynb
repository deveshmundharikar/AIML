# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("IMDB Dataset.csv") 
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.duplicated().value_counts()
# Out:
# False    49582
# True       418
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# review       0.0
# sentiment    0.0
# dtype: float64

# %%
df.duplicated().sum()/df.shape[0]*100
# Out:
# 0.836

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
df1=df.copy()

# %%
df1.drop_duplicates(inplace=True,ignore_index=True)

# %%
print("df1 duplicated",df1.duplicated().sum())
print("df is dubplicated",df.duplicated().sum())
# Out:
# df1 duplicated 0
# df is dubplicated 418

# %%
df1.columns
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
df1["sentiment"].value_counts()
# Out:
# sentiment
# positive    24884
# negative    24698
# Name: count, dtype: int64

# %%
df1["review"].value_counts().sum()
# Out:
# 49582

# %%
df1.shape
# Out:
# (49582, 2)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="sentiment", hue="sentiment", data=df1, palette=['#55a868', '#c44e52'], legend=False)
plt.title(" green is positive , red is negative sentiments")
plt.xlabel("sentiment")
plt.ylabel("review")
plt.show()

# %%
p=df1["sentiment"]=="positive"

# %%
p.value_counts()
# Out:
# sentiment
# True     24884
# False    24698
# Name: count, dtype: int64

# %%
df1.value_counts().sum()
# Out:
# 49582

# %%
n=df1["sentiment"]=="negative"        
n.value_counts()
# Out:
# sentiment
# False    24884
# True     24698
# Name: count, dtype: int64

# %%
df1["review_len"]=df1["review"].apply(len)

# %%
df1.shape
# Out:
# (49582, 3)

# %%
df1.head()
# Out:
#                                               review sentiment  review_len
# 0  One of the other reviewers has mentioned that ...  positive        1761
# 1  A wonderful little production. <br /><br />The...  positive         998
# 2  I thought this was a wonderful way to spend ti...  positive         926
# 3  Basically there's a family where a little boy ...  negative         748
# 4  Petter Mattei's "Love in the Time of Money" is...  positive        1317

# %%
plt.figure(figsize=(10,5))
bins=50
sns.histplot(x="review_len",hue="sentiment",data=df1,kde=True,bins=bins,palette=['#c44e52', '#55a868'])
plt.title("sentiment anysis review len distribution")
plt.xlabel("review len")
plt.ylabel("words frequency")
plt.legend(title="sentiment",labels=["p","n"])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x="review_len", hue="sentiment", data=df1)
plt.title("Sentiment Analysis Review Length Distribution")
plt.legend(title="Sentiment", labels=["Positive", "Negative"])
plt.show()

# %%
df1["review_len"].describe()
# Out:
# count    49582.000000
# mean      1310.568230
# std        990.762238
# min         32.000000
# 25%        699.000000
# 50%        971.000000
# 75%       1592.000000
# max      13704.000000
# Name: review_len, dtype: float64

# %%
df1["sentiment"].describe()
# Out:
# count        49582
# unique           2
# top       positive
# freq         24884
# Name: sentiment, dtype: object

# %%
print(df1.groupby('sentiment')['review_len'].describe())
# Out:
#              count         mean          std   min    25%    50%      75%  \
# sentiment
# negative   24698.0  1294.739615   946.501793  32.0  706.0  974.0  1568.00
# positive   24884.0  1326.278532  1032.597204  65.0  692.0  969.0  1615.25
#
#                max
# sentiment
# negative    8969.0
# positive   13704.0

# %%
#data preprocessing 
import re 
import nltk 
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
try:
    stopwords.words('english')
except LookupError:
    print("Downloading NLTK stopwords...")
    nltk.download('stopwords')

# %%
try:
    nltk.data.find('corpora/wordnet.zip')
except LookupError:
    print("Downloading NLTK wordnet...")
    nltk.download('wordnet')

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %% [markdown]
# 1 Removes HTML tags
# 2 Removes special characters numbers and punctuation
# 3 Converts to lowercase.
# 4 Tokenizes text (splits into words)
# 5 Removes stopwords
# 6 Lemmatizes words

# %%
def clean_text(text):
    # 1. Remove HTML tags
    soup = BeautifulSoup(text, "html.parser")
    text = soup.get_text()

    # 2. Remove special characters, numbers, and punctuation
    text = re.sub(r'[^a-zA-Z\s]', '', text, re.I | re.A)

    # 3. Convert to lowercase
    text = text.lower()

    # 4–6. Tokenize, remove stopwords, and lemmatize
    cleaned_words = []
    for word in text.split():
        if word not in stop_words:
            cleaned_words.append(lemmatizer.lemmatize(word))

    return " ".join(cleaned_words)

# %%
df1['cleaned_review'] = df1['review'].apply(clean_text)
print(df['review'].iloc[1])
# Out:
# C:\Users\Rooknight\AppData\Local\Temp\ipykernel_19824\40878922.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# ...

# %%
print(df1['cleaned_review'].iloc[1])
# Out:
# wonderful little production filming technique unassuming oldtimebbc fashion give comforting sometimes discomforting sense realism entire piece actor extremely well chosen michael sheen got polari voice pat truly see seamless editing guided reference williams diary entry well worth watching terrificly written performed piece masterful production one great master comedy life realism really come home little thing fantasy guard rather use traditional dream technique remains solid disappears play knowledge sens particularly scene concerning orton halliwell set particularly flat halliwells mural decorating every surface terribly well done

# %%
from wordcloud import WordCloud

#  Word Cloud for Positive Reviews 
positive_text = " ".join(review for review in df1[df1['sentiment'] == 'positive']['cleaned_review'])
wordcloud_positive = WordCloud(
    max_words=100,
    background_color='white',
    colormap='viridis' # Green-ish colormap
).generate(positive_text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Most Common Words in Positive Reviews', fontsize=20)
plt.axis('off')
plt.show()

# %%
# Word Cloud for Negative Reviews 
negative_text = " ".join(review for review in df1[df1['sentiment'] == 'negative']['cleaned_review'])
wordcloud_negative = WordCloud(
    max_words=100,
    background_color='black',
    colormap='Reds' # Red-ish colormap
).generate(negative_text)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Most Common Words in Negative Reviews', fontsize=20)
plt.axis('off')
plt.show()

# %%
x = df1['cleaned_review']
y = df1['sentiment']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
print("shape of :- ",x_train.shape)
print("shape of :- ",y_train.shape)
print("shape of :- ",x_test.shape)
print("shape of :- ",y_test.shape)
# Out:
# shape of :-  (39665,)
# shape of :-  (39665,)
# shape of :-  (9917,)
# shape of :-  (9917,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=20000)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# %%
print("shape of ",x_train_tfidf.shape) 
print("shape of ",x_train_tfidf.shape)
# Out:
# shape of  (39665, 20000)
# shape of  (39665, 20000)

# %%
from sklearn.linear_model import LogisticRegression
baseline_model = LogisticRegression(solver='liblinear', random_state=42)
baseline_model.fit(x_train_tfidf, y_train)
y_pred = baseline_model.predict(x_test_tfidf)
print(y_pred)  
print(baseline_model.score(x_test_tfidf,y_test))
# Out:
# ['positive' 'negative' 'negative' ... 'positive' 'positive' 'negative']
# 0.892104467076737

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
accuracy = accuracy_score(y_test, y_pred)
print("accuracy of model",accuracy) 
print("classification_report",classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# accuracy of model 0.892104467076737
# classification_report               precision    recall  f1-score   support
#
#     negative       0.90      0.88      0.89      4946
#     positive       0.88      0.90      0.89      4971
#
#     accuracy                           0.89      9917
#    macro avg       0.89      0.89      0.89      9917
# weighted avg       0.89      0.89      0.89      9917
#
# [[4361  585]
#  [ 485 4486]]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm,annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Negative', 'Positive'], 
            yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Baseline Model')
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_model = MultinomialNB()
nb_model.fit(x_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
y_pred_nb = nb_model.predict(x_test_tfidf)
print(nb_model.predict(x_test_tfidf)) 
print(nb_model.score(x_test_tfidf,y_test))
# Out:
# ['positive' 'negative' 'negative' ... 'positive' 'positive' 'negative']
# 0.8701220127054553

# %%
accuracy_nb = accuracy_score(y_test, y_pred_nb) 
print(accuracy_nb)
# Out:
# 0.8701220127054553

# %%
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.87      0.87      4946
#     positive       0.87      0.87      0.87      4971
#
#     accuracy                           0.87      9917
#    macro avg       0.87      0.87      0.87      9917
# weighted avg       0.87      0.87      0.87      9917

# %%
cm_nb = confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Greens', 
            xticklabels=['Negative', 'Positive'], 
            yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Naive Bayes Model')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV  
from sklearn.linear_model import LogisticRegression

# %%
lr_model = LogisticRegression(random_state=42)
param_grid = {
    'C': [0.1, 0.5, 1, 5, 10],  
    'solver': ['liblinear']    
}

grid_search = GridSearchCV(estimator=lr_model, 
                           param_grid=param_grid, 
                           cv=5, 
                           n_jobs=-1, 
                           verbose=2)
grid_search.fit(x_train_tfidf, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42), n_jobs=-1,
#              param_grid={'C': [0.1, 0.5, 1, 5, 10], 'solver': ['liblinear']},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'C': 5, 'solver': 'liblinear'}

# %%
grid_search.best_score_
# Out:
# 0.8919450397075508

# %%
best_lr_model = grid_search.best_estimator_
y_pred_tuning= best_lr_model.predict(x_test_tfidf)

accuracy_tuned = accuracy_score(y_test, y_pred_tuning)
print(accuracy_tuned)
# Out:
# 0.8951295754764546

# %%
print(accuracy)
print(accuracy_tuned )
# Out:
# 0.892104467076737
# 0.8951295754764546
