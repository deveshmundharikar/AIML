# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### simple imputer

# %%
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv(r"C:\Users\Rooknight\Downloads\flightdata.csv")

# %%
df.head()
# Out:
#    MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0      54993  11-02-2006        12/24/2008   Male         6            .
# 1      28065   2/19/2007        08-03-2007   Male         6          NaN
# 2      55106  02-01-2007         8/30/2007   Male         6            .
# 3      21189   8/22/2008         8/23/2008   Male         5  Los Angeles
# 4      39546  04-10-2009         4/15/2009   Male         6      guiyang
#
#   WORK_PROVINCE WORK_COUNTRY   AGE  LOAD_TIME  ...  SUM_YR_2  SEG_KM_SUM  \
# 0       beijing           CN  31.0  3/31/2014  ...  234188.0      580717
# 1       beijing           CN  42.0  3/31/2014  ...  167434.0      293678
# 2       beijing           CN  40.0  3/31/2014  ...  164982.0      283712
# 3            CA           US  64.0  3/31/2014  ...  125500.0      281336
# 4       guizhou           CN  48.0  3/31/2014  ...  130702.0      309928
#
#    LAST_FLIGHT_DATE  LAST_TO_END  AVG_INTERVAL MAX_INTERVAL  EXCHANGE_COUNT  \
# ...

# %%
df.isnull().sum()
# Out:
# MEMBER_NO               0
# FFP_DATE                0
# FIRST_FLIGHT_DATE       0
# GENDER                  3
# FFP_TIER                0
# WORK_CITY            2269
# WORK_PROVINCE        3248
# WORK_COUNTRY           26
# AGE                   420
# LOAD_TIME               0
# FLIGHT_COUNT            0
# BP_SUM                  0
# SUM_YR_1              551
# SUM_YR_2              138
# SEG_KM_SUM              0
# LAST_FLIGHT_DATE        0
# LAST_TO_END             0
# AVG_INTERVAL            0
# MAX_INTERVAL            0
# EXCHANGE_COUNT          0
# avg_discount            0
# Points_Sum              0
# Point_NotFlight         0
# dtype: int64

# %%
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#    MEMBER_NO    FFP_DATE FIRST_FLIGHT_DATE GENDER  FFP_TIER    WORK_CITY  \
# 0      54993  11-02-2006        12/24/2008   Male         6            .
# 1      28065   2/19/2007        08-03-2007   Male         6          NaN
# 2      55106  02-01-2007         8/30/2007   Male         6            .
# 3      21189   8/22/2008         8/23/2008   Male         5  Los Angeles
# 4      39546  04-10-2009         4/15/2009   Male         6      guiyang
#
#   WORK_PROVINCE WORK_COUNTRY   AGE  LOAD_TIME  FLIGHT_COUNT  BP_SUM  SUM_YR_1  \
# 0       beijing           CN  31.0  3/31/2014           210  505308  239560.0
# 1       beijing           CN  42.0  3/31/2014           140  362480  171483.0
# 2       beijing           CN  40.0  3/31/2014           135  351159  163618.0
# 3            CA           US  64.0  3/31/2014            23  337314  116350.0
# 4       guizhou           CN  48.0  3/31/2014           152  273844  124560.0
#
# ...

# %%
x=df.drop(columns="SUM_YR_2",axis=1)
y=df["SUM_YR_2"] 
print("shape od x ", x.shape)
print(" shape of y", y.shape)
# Out:
# shape od x  (62988, 22)
#  shape of y (62988,)

# %% [markdown]
# ##  numerical missing value imputation

# %%
num_col_num=x.select_dtypes(include=["int","float"]).columns

# %%
num_col_num
# Out:
# Index(['MEMBER_NO', 'FFP_TIER', 'AGE', 'FLIGHT_COUNT', 'BP_SUM', 'SUM_YR_1',
#        'SEG_KM_SUM', 'LAST_TO_END', 'AVG_INTERVAL', 'MAX_INTERVAL',
#        'EXCHANGE_COUNT', 'avg_discount', 'Points_Sum', 'Point_NotFlight'],
#       dtype='object')

# %%
num_col_num
num_col_num3=x.select_dtypes(include=["int","float"])

# %%
num_col_num3
# Out:
#        MEMBER_NO  FFP_TIER   AGE  FLIGHT_COUNT  BP_SUM  SUM_YR_1  SEG_KM_SUM  \
# 0          54993         6  31.0           210  505308  239560.0      580717
# 1          28065         6  42.0           140  362480  171483.0      293678
# 2          55106         6  40.0           135  351159  163618.0      283712
# 3          21189         5  64.0            23  337314  116350.0      281336
# 4          39546         6  48.0           152  273844  124560.0      309928
# ...          ...       ...   ...           ...     ...       ...         ...
# 62983      18375         4  25.0             2       0       0.0        1134
# 62984      36041         4  38.0             4       0       0.0        8016
# 62985      45690         4  43.0             2       0       0.0        2594
# 62986      61027         4  36.0             2       0       0.0        3934
# 62987      61340         4  29.0             2       0       NaN        4222
#
# ...

# %%
num_col_num.isnull().sum()
# Out:
# 0

# %%
from sklearn.impute import SimpleImputer

# %%
# you also use median and mode
#imputer_mean=SimpleImputer(strategy='constant',fill_value=20)  
imputer_mean=SimpleImputer(strategy='mean')

# %%
imputer_mean.fit(x[num_col_num])
# Out:
# SimpleImputer()

# %%
#attribute 
imputer_mean.statistics_
# Out:
# array([3.14945000e+04, 4.10216232e+00, 4.24763457e+01, 1.18394139e+01,
#        1.09250813e+04, 5.35537606e+03, 1.71238787e+04, 1.76120102e+02,
#        6.77497879e+01, 1.66033895e+02, 3.19775195e-01, 7.21557771e-01,
#        1.25457771e+04, 2.72815457e+00])

# %%
#trasform data 
imputer_mean.transform(x[num_col_num])
# Out:
# array([[5.49930000e+04, 6.00000000e+00, 3.10000000e+01, ...,
#         9.61639043e-01, 6.19760000e+05, 5.00000000e+01],
#        [2.80650000e+04, 6.00000000e+00, 4.20000000e+01, ...,
#         1.25231444e+00, 4.15768000e+05, 3.30000000e+01],
#        [5.51060000e+04, 6.00000000e+00, 4.00000000e+01, ...,
#         1.25467552e+00, 4.06361000e+05, 2.60000000e+01],
#        ...,
#        [4.56900000e+04, 4.00000000e+00, 4.30000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.10270000e+04, 4.00000000e+00, 3.60000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.13400000e+04, 4.00000000e+00, 2.90000000e+01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
#2d array data  
#train and test data ko sath me impute karna padta hai

# %%
x[num_col_num]=imputer_mean.transform(x[num_col_num])

# %%
x[num_col_num].isnull().sum()
# Out:
# MEMBER_NO          0
# FFP_TIER           0
# AGE                0
# FLIGHT_COUNT       0
# BP_SUM             0
# SUM_YR_1           0
# SEG_KM_SUM         0
# LAST_TO_END        0
# AVG_INTERVAL       0
# MAX_INTERVAL       0
# EXCHANGE_COUNT     0
# avg_discount       0
# Points_Sum         0
# Point_NotFlight    0
# dtype: int64

# %% [markdown]
# ## categorical missing value imputation

# %% [markdown]
# ## categorical missing value imputation mode

# %%
cat_col=x.select_dtypes(include=["object"])

# %%
cat_col.isnull().sum()
# Out:
# FFP_DATE                0
# FIRST_FLIGHT_DATE       0
# GENDER                  3
# WORK_CITY            2269
# WORK_PROVINCE        3248
# WORK_COUNTRY           26
# LOAD_TIME               0
# LAST_FLIGHT_DATE        0
# dtype: int64

# %%
cat_col.info
# Out:
# <bound method DataFrame.info of          FFP_DATE FIRST_FLIGHT_DATE  GENDER    WORK_CITY WORK_PROVINCE  \
# 0      11-02-2006        12/24/2008    Male            .       beijing
# 1       2/19/2007        08-03-2007    Male          NaN       beijing
# 2      02-01-2007         8/30/2007    Male            .       beijing
# 3       8/22/2008         8/23/2008    Male  Los Angeles            CA
# 4      04-10-2009         4/15/2009    Male      guiyang       guizhou
# ...           ...               ...     ...          ...           ...
# 62983   5/20/2011        06-05-2013  Female    guangzhou     guangdong
# 62984  03-08-2010         9/14/2013    Male       foshan     guangdong
# 62985   3/30/2006        12-02-2006  Female    guangzhou     guangdong
# 62986  02-06-2013         2/14/2013  Female    guangzhou     guangdong
# 62987   2/17/2013         2/17/2013  Female     shanghai             .
#
#       WORK_COUNTRY  LOAD_TIME LAST_FLIGHT_DATE
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
#imputer_mode=SimpleImputer( strategy='mode')

# %%
#imputer_mode.fit(x[cat_col]) 
#imputer_mode.statistics_ 
#imputer_mode.transform(x[cat_col3]) 
#x[cat_col]=imputer_mean.transform(x[cat_col]) 
#x[cat_col].isnull().sum()

# %%
cat_col.isnull().sum()
# Out:
# FFP_DATE                0
# FIRST_FLIGHT_DATE       0
# GENDER                  3
# WORK_CITY            2269
# WORK_PROVINCE        3248
# WORK_COUNTRY           26
# LOAD_TIME               0
# LAST_FLIGHT_DATE        0
# dtype: int64

# %%
cat_col3=['GENDER', 'WORK_CITY']

# %%
imputer_mode=SimpleImputer( strategy='most_frequent')

# %%
imputer_mode.fit(x[cat_col3])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
imputer_mode.transform(x[cat_col3])
# Out:
# array([['Male', '.'],
#        ['Male', 'guangzhou'],
#        ['Male', '.'],
#        ...,
#        ['Female', 'guangzhou'],
#        ['Female', 'guangzhou'],
#        ['Female', 'shanghai']], dtype=object)

# %%
imputer_mode.transform(x[cat_col3])
# Out:
# array([['Male', '.'],
#        ['Male', 'guangzhou'],
#        ['Male', '.'],
#        ...,
#        ['Female', 'guangzhou'],
#        ['Female', 'guangzhou'],
#        ['Female', 'shanghai']], dtype=object)

# %%
#how to check in mode value  
imputer_mode.statistics_
# Out:
# array(['Male', 'guangzhou'], dtype=object)

# %%
#x[cat_col]=imputer_mean.transform(x[cat_col]) 
x[cat_col3]=imputer_mode.transform(x[cat_col3])

# %%
x[cat_col3].isnull().sum()
# Out:
# GENDER       0
# WORK_CITY    0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
#globla constant

# %%
#imputer=SimpleImputer(strategy='constant',fill_value=99)
