# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Rooknight\Downloads\houseprice.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#2
df.select_dtypes(include=["int"]).columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking'], dtype='object')

# %%
df.select_dtypes(include=["object"]).columns
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.sample(10)
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 98   6293000   6600         3          2        3      yes        no       no
# 48   7455000   4300         3          2        2      yes        no      yes
# 203  4900000   5400         4          1        2      yes        no       no
# 167  5285000   4600         2          2        1      yes        no       no
# 303  4200000   4500         3          1        1      yes        no      yes
# 274  4340000   6450         4          1        2      yes        no       no
# 49   7420000   7440         3          2        1      yes       yes      yes
# 191  5040000  10700         3          1        2      yes       yes      yes
# 523  2380000   2787         4          2        2      yes        no       no
# 319  4060000   3000         4          1        3      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
#2
df["furnishingstatus"].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
df["parking"].value_counts()
# Out:
# parking
# 0    299
# 1    126
# 2    108
# 3     12
# Name: count, dtype: int64

# %%
df_per=df.isnull().sum()/df.shape[0]*100

# %%
#2
check_in=df_per[df_per > 20].keys()  
check_in.shape
# Out:
# (0,)

# %%
#drop

drop_20_per = df.drop(columns=check_in) 
drop_20_per
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#pd.set_option('display.max_columns',None)  
#pd.set_option('display.max_rows',None)

# %%
#showing null data  look out null value 
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %%
 #column categorical variable classecs check 
df["furnishingstatus"].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
#categorical  selecrt fertuere 
df[df.loc[:,"furnishingstatus"]=="semi-furnished"]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2    12250000  9960         3          2        2      yes        no      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# 6    10150000  8580         4          3        4      yes        no       no
# 11    9681000  6000         4          3        2      yes       yes      yes
# 12    9310000  6550         4          2        2      yes        no       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 502   2660000  3480         2          1        1      yes        no       no
# 503   2660000  4000         3          1        1      yes        no       no
# 514   2485000  3000         3          1        2       no        no       no
# 527   2275000  1836         2          1        1       no        no      yes
# 541   1767150  2400         3          1        1       no        no       no
#
# ...

# %%
df[df.loc[:,"furnishingstatus"]=="semi-furnished"]["price"]
# Out:
# 2      12250000
# 5      10850000
# 6      10150000
# 11      9681000
# 12      9310000
#          ...
# 502     2660000
# 503     2660000
# 514     2485000
# 527     2275000
# 541     1767150
# Name: price, Length: 227, dtype: int64

# %%
#catrgorical  percent 
cat_var=df.select_dtypes(include=['object'])

# %%
cat_per=cat_var.isnull().mean()*100

# %%
cat_per
# Out:
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %%
#fillna value

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
#mean for categorical data

df_fiilll=cat_per.fillna(cat_per.mean())

# %%
num_var=df.select_dtypes(include=['int'])

# %%
df_fillll=num_var.fillna(num_var.median())

# %%
df_meannn=num_var.fillna(num_var.mean())
